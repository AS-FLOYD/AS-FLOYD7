# %% [markdown]
# # EXPLORATORY DATA ANALYSIS
#
# Import the Necessary Libraries :

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
pd.options.display.float_format = '{:.2f}'.format
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv(r'C:\Users\ABHIJIT FLOYD\OneDrive\Desktop\Documents\Internship\creditcard.csv')
df.head()
# Out:
#    Time    V1    V2   V3    V4    V5    V6    V7    V8    V9  ...   V21   V22  \
# 0  0.00 -1.36 -0.07 2.54  1.38 -0.34  0.46  0.24  0.10  0.36  ... -0.02  0.28
# 1  0.00  1.19  0.27 0.17  0.45  0.06 -0.08 -0.08  0.09 -0.26  ... -0.23 -0.64
# 2  1.00 -1.36 -1.34 1.77  0.38 -0.50  1.80  0.79  0.25 -1.51  ...  0.25  0.77
# 3  1.00 -0.97 -0.19 1.79 -0.86 -0.01  1.25  0.24  0.38 -1.39  ... -0.11  0.01
# 4  2.00 -1.16  0.88 1.55  0.40 -0.41  0.10  0.59 -0.27  0.82  ... -0.01  0.80
#
#     V23   V24   V25   V26   V27   V28  Amount  Class
# 0 -0.11  0.07  0.13 -0.19  0.13 -0.02  149.62      0
# 1  0.10 -0.34  0.17  0.13 -0.01  0.01    2.69      0
# 2  0.91 -0.69 -0.33 -0.14 -0.06 -0.06  378.66      0
# 3 -0.19 -1.18  0.65 -0.22  0.06  0.06  123.50      0
# 4 -0.14  0.14 -0.21  0.50  0.22  0.22   69.99      0
#
# [5 rows x 31 columns]

# %% [markdown]
# Data Info :

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %% [markdown]
# Analysing the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %% [markdown]
# Its a huge dataset with around 284k entries, 31 columns, and all our data is in numerical data type so theres no need to convert
# Also there are no null values in our data, which means theres no need of data cleaning to be done!!

# %%
df.describe().T
# Out:
#            count     mean      std     min      25%      50%       75%  \
# Time   284807.00 94813.86 47488.15    0.00 54201.50 84692.00 139320.50
# V1     284807.00     0.00     1.96  -56.41    -0.92     0.02      1.32
# V2     284807.00     0.00     1.65  -72.72    -0.60     0.07      0.80
# V3     284807.00    -0.00     1.52  -48.33    -0.89     0.18      1.03
# V4     284807.00     0.00     1.42   -5.68    -0.85    -0.02      0.74
# V5     284807.00    -0.00     1.38 -113.74    -0.69    -0.05      0.61
# V6     284807.00     0.00     1.33  -26.16    -0.77    -0.27      0.40
# V7     284807.00    -0.00     1.24  -43.56    -0.55     0.04      0.57
# V8     284807.00    -0.00     1.19  -73.22    -0.21     0.02      0.33
# V9     284807.00    -0.00     1.10  -13.43    -0.64    -0.05      0.60
# V10    284807.00     0.00     1.09  -24.59    -0.54    -0.09      0.45
# V11    284807.00     0.00     1.02   -4.80    -0.76    -0.03      0.74
# V12    284807.00    -0.00     1.00  -18.68    -0.41     0.14      0.62
# V13    284807.00     0.00     1.00   -5.79    -0.65    -0.01      0.66
# V14    284807.00     0.00     0.96  -19.21    -0.43     0.05      0.49
# V15    284807.00     0.00     0.92   -4.50    -0.58     0.05      0.65
# V16    284807.00     0.00     0.88  -14.13    -0.47     0.07      0.52
# V17    284807.00    -0.00     0.85  -25.16    -0.48    -0.07      0.40
# V18    284807.00     0.00     0.84   -9.50    -0.50    -0.00      0.50
# V19    284807.00     0.00     0.81   -7.21    -0.46     0.00      0.46
# V20    284807.00     0.00     0.77  -54.50    -0.21    -0.06      0.13
# V21    284807.00     0.00     0.73  -34.83    -0.23    -0.03      0.19
# V22    284807.00     0.00     0.73  -10.93    -0.54     0.01      0.53
# V23    284807.00     0.00     0.62  -44.81    -0.16    -0.01      0.15
# V24    284807.00     0.00     0.61   -2.84    -0.35     0.04      0.44
# V25    284807.00     0.00     0.52  -10.30    -0.32     0.02      0.35
# V26    284807.00     0.00     0.48   -2.60    -0.33    -0.05      0.24
# V27    284807.00    -0.00     0.40  -22.57    -0.07     0.00      0.09
# V28    284807.00    -0.00     0.33  -15.43    -0.05     0.01      0.08
# Amount 284807.00    88.35   250.12    0.00     5.60    22.00     77.16
# Class  284807.00     0.00     0.04    0.00     0.00     0.00      0.00
#
#              max
# Time   172792.00
# V1          2.45
# V2         22.06
# V3          9.38
# V4         16.88
# V5         34.80
# V6         73.30
# V7        120.59
# V8         20.01
# V9         15.59
# V10        23.75
# V11        12.02
# V12         7.85
# V13         7.13
# V14        10.53
# V15         8.88
# V16        17.32
# V17         9.25
# V18         5.04
# V19         5.59
# V20        39.42
# V21        27.20
# V22        10.50
# V23        22.53
# V24         4.58
# V25         7.52
# V26         3.52
# V27        31.61
# V28        33.85
# Amount  25691.16
# Class       1.00

# %% [markdown]
# There seems to be a lot of skewness in our data which can be visually analysed for better understanding

# %% [markdown]
# # REMOVING DUPLICATE ENTRIES

# %%
df.duplicated().sum()
# Out:
# 1081

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (283726, 31)

# %% [markdown]
# # CHECKING CORRELATION

# %%
df.corr().style.background_gradient()
# Out:
# <style type="text/css">
# #T_adfed_row0_col0, #T_adfed_row1_col1, #T_adfed_row2_col2, #T_adfed_row3_col3, #T_adfed_row4_col4, #T_adfed_row5_col5, #T_adfed_row6_col6, #T_adfed_row7_col7, #T_adfed_row8_col8, #T_adfed_row9_col9, #T_adfed_row10_col10, #T_adfed_row11_col11, #T_adfed_row12_col12, #T_adfed_row13_col13, #T_adfed_row14_col14, #T_adfed_row15_col15, #T_adfed_row16_col16, #T_adfed_row17_col17, #T_adfed_row18_col18, #T_adfed_row19_col19, #T_adfed_row20_col20, #T_adfed_row21_col21, #T_adfed_row22_col22, #T_adfed_row23_col23, #T_adfed_row24_col24, #T_adfed_row25_col25, #T_adfed_row26_col26, #T_adfed_row27_col27, #T_adfed_row28_col28, #T_adfed_row29_col29, #T_adfed_row30_col30 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_adfed_row0_col1, #T_adfed_row2_col5 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_adfed_row0_col2, #T_adfed_row0_col29, #T_adfed_row12_col29 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_adfed_row0_col3, #T_adfed_row0_col4, #T_adfed_row0_col6, #T_adfed_row0_col11, #T_adfed_row0_col13, #T_adfed_row0_col15, #T_adfed_row0_col20, #T_adfed_row0_col24, #T_adfed_row0_col25, #T_adfed_row0_col26, #T_adfed_row1_col27, #T_adfed_row2_col21, #T_adfed_row2_col29, #T_adfed_row3_col0, #T_adfed_row11_col21, #T_adfed_row17_col30, #T_adfed_row23_col21, #T_adfed_row27_col21, #T_adfed_row27_col28, #T_adfed_
{
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_adfed_row1_col0 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_adfed_row1_col2, #T_adfed_row7_col2, #T_adfed_row11_col30, #T_adfed_row17_col29, #T_adfed_row27_col2, #T_adfed_row28_col29, #T_adfed_row30_col29 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_adfed_row1_col3, #T_adfed_row2_col0, #T_adfed_row5_col3, #T_adfed_row9_col0, #T_adfed_row10_col3, #T_adfed_row12_col3, #T_adfed_row17_col3, #T_adfed_row27_col3, #T_adfed_row28_col0, #T_adfed_row29_col0 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_adfed_row1_col4, #T_adfed_row1_col23, #T_adfed_row2_col23, #T_adfed_row3_col4, #T_adfed_row3_col23, #T_adfed_row3_col30, #T_adfed_row4_col23, #T_adfed_row5_col2

# %% [markdown]
# # CHECKING UNIQUE VALUES IN OUR DATASET

# %%
df.nunique()
# Out:
# Time      124592
# V1        275663
# V2        275663
# V3        275663
# V4        275663
# V5        275663
# V6        275663
# V7        275663
# V8        275663
# V9        275663
# V10       275663
# V11       275663
# V12       275663
# V13       275663
# V14       275663
# V15       275663
# V16       275663
# V17       275663
# V18       275663
# V19       275663
# V20       275663
# V21       275663
# V22       275663
# V23       275663
# V24       275663
# V25       275663
# V26       275663
# V27       275663
# V28       275663
# Amount     32767
# Class          2
# dtype: int64

# %%
from scipy.stats import skew
col=df.columns[:-1]
for i in col:
    if (skew(df[i]>0.2)):
        print(i)
        print(skew(df[i]))
    
        plt.figure(figsize=(10,2))
        sns.distplot(df[i])
        plt.show()
# Out:
# Time
# -0.03558045812827333
# V1
# -3.2732539433146486
# V2
# -4.695137078165384
# V3
# -2.1519725799940685
# V4
# 0.6715006205655543
# V5
# -2.414066484215612
# V6
# 1.829870709562578
# V7
# 2.8902559124339735
# V8
# -8.310926391626731
# V9
# 0.5376602109334492
# V10
# 1.2529604545622932
# V11
# 0.34407237420591985
# V12
# -2.198996655901221
# V13
# 0.06429306473390328
# V14
# -1.9187935694299705
# V15
# -0.3096574451884751
# V16
# -1.0511559142385323
# V17
# -3.690477683233225
# V18
# -0.24866014274940992
# V19
# 0.1083112383097532
# V20
# -2.043110254457915
# V21
# 2.8200182046255926
# V22
# -0.18232876403467282
# V23
# -5.867189772192024
# V24
# -0.5521263176758532
# V25
# -0.41574166410065255
# V26
# 0.5802892493462333
# V27
# -0.7537999286092231
# V28
# 11.555053994631207
# Amount
# 16.978713606547593

# %% [markdown]
# # CHECKING TARGET DISTRIBUTION

# %%
df['Class'].value_counts()
# Out:
# 0    283253
# 1       473
# Name: Class, dtype: int64

# %% [markdown]
# Our data seems to be highly imbalanced so we need to stratify and use GridSerachCrossValidation to obtain best results

# %% [markdown]
# # CREATING A DATAFRAME WITH BALANCED TARGET DATA SO THAT OUR MODEL CAN MAKE ACCURATE PREDICTIONS

# %%
x=df.sample(473,random_state=1)[df['Class']==0]
y=df[df['Class']==1]
newdf=pd.concat([x,y],axis=0)
sns.countplot(data=newdf,x='Class')
# Out:
# <AxesSubplot:xlabel='Class', ylabel='count'>

# %% [markdown]
# Our data is now balanced and target is equally distributed

# %%
newdf.sample(10)
# Out:
#             Time    V1    V2    V3    V4    V5    V6    V7     V8    V9  ...  \
# 218381 141294.00 -0.96  0.90  0.26 -0.26  1.19 -1.30  1.52  -2.22  0.89  ...
# 39031   39663.00  1.09  0.52  0.86  2.36 -0.08  0.13 -0.06   0.18 -1.00  ...
# 151807  96291.00 -3.55  5.43 -3.73  6.68 -2.19  2.43 -8.75 -12.11 -2.86  ...
# 217377 140867.00  1.81 -0.37 -0.61  1.35 -0.01  0.49 -0.24   0.13  0.87  ...
# 541       406.00 -2.31  1.95 -1.61  4.00 -0.52 -1.43 -2.54   1.39 -2.77  ...
# 189587 128471.00  0.91  1.34 -4.48  3.25 -0.42 -0.76 -2.51   0.69 -0.47  ...
# 108708  71033.00 -3.17  0.19 -3.40  3.76 -2.15 -1.60 -2.52   1.32 -2.40  ...
# 133802  80537.00  1.22  0.27  0.18  0.51 -0.16 -0.56 -0.02  -0.04 -0.20  ...
# 50537   44532.00 -0.23  0.36  1.97 -1.26 -0.68 -0.67  0.06  -0.00  1.12  ...
# 255415 157211.00  2.02 -0.21 -0.52  0.27 -0.21 -0.13 -0.44  -0.04  1.11  ...
#
#          V21   V22   V23   V24   V25   V26   V27   V28  Amount  Class
# 218381  0.95  1.00 -0.16  0.32 -0.61 -0.35 -1.28 -0.38    8.01      0
# 39031  -0.16 -0.54  0.19  0.16  0.11 -0.27  0.01  0.02    1.30      0
# 151807 -5.69  2.51  0.95 -0.54 -0.62  0.41  0.02  0.16   33.59      1
# 217377 -0.47 -1.19  0.28 -0.87 -0.27 -1.08  0.05 -0.04   69.57      0
# 541     0.52 -0.04 -0.47  0.32  0.04  0.18  0.26 -0.14    0.00      1
# 189587  0.59  0.59 -0.25  0.33  0.56 -0.26  0.65  0.32   67.90      1
# 108708  1.09 -0.04  0.90  0.18  0.05 -0.26  0.86  0.23  426.40      1
# 133802 -0.25 -0.78  0.07 -0.04  0.23  0.10 -0.03  0.02    8.81      0
# 50537   0.22  0.91 -0.29  0.45  0.19 -0.53  0.12  0.04    1.00      1
# 255415 -0.19 -0.38  0.36  0.46 -0.33 -0.64  0.04 -0.02    5.00      0
#
# [10 rows x 31 columns]

# %%
x=newdf.iloc[:,:-1]
y=newdf.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,random_state=2,test_size=0.25,stratify=y)

# %% [markdown]
# # CREATING A FUNCTION TO TEST MULTIPLE MODELS EFFECTIVELY

# %%
def mymodel(model):
    model.fit(xtrain,ytrain)
    ypred=model.predict(xtest)
    
    tr=model.score(xtrain,ytrain)
    te=model.score(xtest,ytest)
    
    print(str(model)[:-2],'Accuracy: ',accuracy_score(ytest,ypred),\
          '\nConfusion Matrix: \n',confusion_matrix(ytest,ypred))
    print("Classification report: \n",classification_report(ytest,ypred))
    print(f'Training Accuracy: {tr}\nTesting Accuracy: {te}')
    
    return model

# %% [markdown]
# Importing necessary models and metrics to check our model accuracy

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier

# %%
knn=mymodel(KNeighborsClassifier())
# Out:
# KNeighborsClassifier Accuracy:  0.6540084388185654
# Confusion Matrix:
#  [[81 38]
#  [44 74]]
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.65      0.68      0.66       119
#            1       0.66      0.63      0.64       118
#
#     accuracy                           0.65       237
#    macro avg       0.65      0.65      0.65       237
# weighted avg       0.65      0.65      0.65       237
#
# Training Accuracy: 0.7602256699576869
# Testing Accuracy: 0.6540084388185654

# %% [markdown]
# Not a good model as the accuracy is very low

# %%
svc=mymodel(SVC())
# Out:
# SVC Accuracy:  0.5443037974683544
# Confusion Matrix:
#  [[66 53]
#  [55 63]]
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.55      0.55      0.55       119
#            1       0.54      0.53      0.54       118
#
#     accuracy                           0.54       237
#    macro avg       0.54      0.54      0.54       237
# weighted avg       0.54      0.54      0.54       237
#
# Training Accuracy: 0.5331452750352609
# Testing Accuracy: 0.5443037974683544

# %% [markdown]
# again not an effective model

# %%
dt=mymodel(DecisionTreeClassifier())
# Out:
# DecisionTreeClassifier Accuracy:  0.890295358649789
# Confusion Matrix:
#  [[107  12]
#  [ 14 104]]
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.90      0.89       119
#            1       0.90      0.88      0.89       118
#
#     accuracy                           0.89       237
#    macro avg       0.89      0.89      0.89       237
# weighted avg       0.89      0.89      0.89       237
#
# Training Accuracy: 1.0
# Testing Accuracy: 0.890295358649789

# %% [markdown]
# Accuracy for Decision tree model is better but its also a case of overfitting which we dont want

# %%
gnb=mymodel(GaussianNB())
# Out:
# GaussianNB Accuracy:  0.8734177215189873
# Confusion Matrix:
#  [[119   0]
#  [ 30  88]]
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.80      1.00      0.89       119
#            1       1.00      0.75      0.85       118
#
#     accuracy                           0.87       237
#    macro avg       0.90      0.87      0.87       237
# weighted avg       0.90      0.87      0.87       237
#
# Training Accuracy: 0.8631875881523272
# Testing Accuracy: 0.8734177215189873

# %% [markdown]
# Its so far the best model but lets check if we can find an even better model

# %%
lr=mymodel(LogisticRegression())
# Out:
# LogisticRegression Accuracy:  0.9409282700421941
# Confusion Matrix:
#  [[115   4]
#  [ 10 108]]
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.97      0.94       119
#            1       0.96      0.92      0.94       118
#
#     accuracy                           0.94       237
#    macro avg       0.94      0.94      0.94       237
# weighted avg       0.94      0.94      0.94       237
#
# Training Accuracy: 0.9337094499294781
# Testing Accuracy: 0.9409282700421941

# %% [markdown]
# Perfect!...Logistic regression is giving the best accuracy with lowest recall and False positive and also the training and testing accuracy doesnt have a huge diff
# Its the best model !!

# %% [markdown]
# Lets try using all data

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,random_state=2,\
                                           test_size=0.25,stratify=y)

# %%
y.value_counts()
# Out:
# 0    283253
# 1       473
# Name: Class, dtype: int64

# %% [markdown]
# # TRAINING AND TESTING ALL CLASSIFICATION MODELS TO FIND THE BEST ONE

# %%
#knn=mymodel(KNeighborsClassifier())

# %%
svc=mymodel(SVC())
# Out:
# SVC Accuracy:  0.9983364348953928
# Confusion Matrix:
#  [[70814     0]
#  [  118     0]]
# Classification report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     70814
#            1       0.00      0.00      0.00       118
#
#     accuracy                           1.00     70932
#    macro avg       0.50      0.50      0.50     70932
# weighted avg       1.00      1.00      1.00     70932
#
# Training Accuracy: 0.9983317198793199
# Testing Accuracy: 0.9983364348953928

# %%
lr=mymodel(LogisticRegression())
# Out:
# LogisticRegression Accuracy:  0.9990554333728078
# Confusion Matrix:
#  [[70786    28]
#  [   39    79]]
# Classification report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     70814
#            1       0.74      0.67      0.70       118
#
#     accuracy                           1.00     70932
#    macro avg       0.87      0.83      0.85     70932
# weighted avg       1.00      1.00      1.00     70932
#
# Training Accuracy: 0.9991165164431328
# Testing Accuracy: 0.9990554333728078

# %%
gnb=mymodel(GaussianNB())
# Out:
# GaussianNB Accuracy:  0.9920205267016298
# Confusion Matrix:
#  [[70292   522]
#  [   44    74]]
# Classification report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     70814
#            1       0.12      0.63      0.21       118
#
#     accuracy                           0.99     70932
#    macro avg       0.56      0.81      0.60     70932
# weighted avg       1.00      0.99      0.99     70932
#
# Training Accuracy: 0.9926078742821696
# Testing Accuracy: 0.9920205267016298

# %%
dt=mymodel(DecisionTreeClassifier())
# Out:
# DecisionTreeClassifier Accuracy:  0.9990554333728078
# Confusion Matrix:
#  [[70784    30]
#  [   37    81]]
# Classification report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     70814
#            1       0.73      0.69      0.71       118
#
#     accuracy                           1.00     70932
#    macro avg       0.86      0.84      0.85     70932
# weighted avg       1.00      1.00      1.00     70932
#
# Training Accuracy: 1.0
# Testing Accuracy: 0.9990554333728078

# %% [markdown]
# We can observe that when we use all the data our model is not effective even though its giving 99% accuracy but the prediction is mostly 0 as our model is learning on 0's and also the recall is very low so lets try with GridSearchCrossValidation

# %% [markdown]
# # CROSS VALIDATION

# %%
x=df.iloc[:10000,:-1]
y=df.iloc[:10000,-1]

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,random_state=2,\
                                           test_size=0.25,stratify=y)

# %%
from sklearn.model_selection import GridSearchCV
parameters={'C':[0.1,10],'gamma':[0.1,0.01,0.001],'kernel':['rbf']}

grid=GridSearchCV(SVC(),parameters,verbose=2)
grid.fit(xtrain,ytrain)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   4.0s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   4.2s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   4.5s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   4.4s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   4.3s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   4.5s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   4.5s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   4.0s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   4.0s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   4.2s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   1.8s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   1.8s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   1.6s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   1.8s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   1.6s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   8.7s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   8.5s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   8.8s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   8.5s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   9.1s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   7.3s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   7.4s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   7.2s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   7.9s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   7.3s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   4.4s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   4.4s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   4.2s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   4.1s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   5.0s
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.1, 10], 'gamma': [0.1, 0.01, 0.001],
#                          'kernel': ['rbf']},
#              verbose=2)

# %%
grid.best_params_
# Out:
# {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}

# %%
grid.best_estimator_
# Out:
# SVC(C=10, gamma=0.001)

# %%
svm=grid.best_estimator_

# %%
svm.fit(xtrain,ytrain)
ypred=svm.predict(xtest)
    
tr=svm.score(xtrain,ytrain)
te=svm.score(xtest,ytest)
    
print('Accuracy: ',accuracy_score(ytest,ypred))
print("Classification report: \n",classification_report(ytest,ypred))
print(f'Training Accuracy: {tr}\nTesting Accuracy: {te}')
# Out:
# Accuracy:  0.9972
# Classification report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2491
#            1       1.00      0.22      0.36         9
#
#     accuracy                           1.00      2500
#    macro avg       1.00      0.61      0.68      2500
# weighted avg       1.00      1.00      1.00      2500
#
# Training Accuracy: 1.0
# Testing Accuracy: 0.9972

# %% [markdown]
# to be continued.....
